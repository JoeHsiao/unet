# %% [markdown]
# # Mount Google Drive

# %%
import os
import glob
from google.colab import drive
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/Carvana_UNet"
# Out:
# 12_tests  model_unet_checkpoint.h5  train  train_masks	UNet.ipynb

# %%
ROOT = '/content/drive/My Drive/Colab Notebooks/Carvana_UNet'
TRAIN_DIR = 'train'
MASK_DIR = 'train_masks'

X_root,_,X_files = next(os.walk(os.path.join(ROOT, TRAIN_DIR)))
y_root,_,y_files = next(os.walk(os.path.join(ROOT, MASK_DIR)))

# %%
TRAIN_SIZE = 1000
train_files = [os.path.join(X_root, f) for f in X_files][:TRAIN_SIZE]
mask_files = [os.path.join(y_root, os.path.splitext(f)[0] + '_mask.gif') for f in X_files][:TRAIN_SIZE]

plt.figure(figsize=(15, 10))
for i, path in enumerate([train_files[0], mask_files[0]]):
  plt.subplot(1, 2, i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  img = plt.imread(path)
  plt.imshow(img)
plt.show()

# %%
import numpy as np
from tqdm import tqdm

IMG_HEIGHT = 320
IMG_WIDTH = 480
IMG_CHANNELS = 3

X_train = np.zeros((len(train_files), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(mask_files), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)

# %%
from PIL import Image

for i, (img_path, mask_path) in tqdm(enumerate(zip(train_files, mask_files)), total=len(train_files)):
  
  img = Image.open(img_path)
  img = img.resize((IMG_WIDTH, IMG_HEIGHT))
  img_arr = np.asarray(img)

  X_train[i] = img_arr

  mask = Image.open(mask_path)
  mask = mask.resize((IMG_WIDTH, IMG_HEIGHT))
  mask_arr = np.asarray(mask)
  mask_arr = np.expand_dims(mask_arr, axis=2)  # reshape to (h, w, 1)

  Y_train[i] = mask_arr

# %% [markdown]
# #Create a UNet Model

# %% [markdown]
# ![](https://drive.google.com/uc?id=1tRvTdQ5eTAl-0vZz2Q4TUs8L2LmRt6pt)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Conv2D, Conv2DTranspose, BatchNormalization, Dropout, MaxPooling2D, concatenate

# %%
# Build U-Net model
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (s)

c1 = BatchNormalization()(c1)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c1)
c1 = BatchNormalization()(c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p1)
c2 = BatchNormalization()(c2)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c2)
c2 = BatchNormalization()(c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p2)
c3 = BatchNormalization()(c3)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c3)
c3 = BatchNormalization()(c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p3)
c4 = BatchNormalization()(c4)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c4)
c4 = BatchNormalization()(c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p4)
c5 = BatchNormalization()(c5)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c5)
c5 = BatchNormalization()(c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u6)
c6 = BatchNormalization()(c6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c6)
c6 = BatchNormalization()(c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u7)
c7 = BatchNormalization()(c7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c7)
c7 = BatchNormalization()(c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u8)
c8 = BatchNormalization()(c8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c8)
c8 = BatchNormalization()(c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u9)
c9 = BatchNormalization()(c9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c9)
c9 = BatchNormalization()(c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

# %%
from tensorflow.keras.models import Model

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 320, 480, 3) 0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 320, 480, 3)  0           input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 320, 480, 32) 896         lambda_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 320, 480, 32) 128         conv2d_38[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 320, 480, 32) 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 320, 480, 32) 9248        dropout_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 320, 480, 32) 128         conv2d_39[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 160, 240, 32) 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 160, 240, 64) 18496       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 160, 240, 64) 256         conv2d_40[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 160, 240, 64) 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 160, 240, 64) 36928       dropout_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 160, 240, 64) 256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 80, 120, 64)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 80, 120, 128) 73856       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 80, 120, 128) 512         conv2d_42[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 80, 120, 128) 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 80, 120, 128) 147584      dropout_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 80, 120, 128) 512         conv2d_43[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 40, 60, 128)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 40, 60, 256)  295168      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 40, 60, 256)  1024        conv2d_44[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 40, 60, 256)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 40, 60, 256)  590080      dropout_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 40, 60, 256)  1024        conv2d_45[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 20, 30, 256)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 20, 30, 512)  1180160     max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 20, 30, 512)  2048        conv2d_46[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 20, 30, 512)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 20, 30, 512)  2359808     dropout_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 20, 30, 512)  2048        conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 40, 60, 128)  262272      batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 40, 60, 384)  0           conv2d_transpose_8[0][0]
#                                                                  batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 40, 60, 256)  884992      concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 40, 60, 256)  1024        conv2d_48[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 40, 60, 256)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 40, 60, 256)  590080      dropout_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 40, 60, 256)  1024        conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 80, 120, 64)  65600       batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 80, 120, 192) 0           conv2d_transpose_9[0][0]
#                                                                  batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 80, 120, 128) 221312      concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 80, 120, 128) 512         conv2d_50[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 80, 120, 128) 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 80, 120, 128) 147584      dropout_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 80, 120, 128) 512         conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 160, 240, 32) 16416       batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 160, 240, 96) 0           conv2d_transpose_10[0][0]
#                                                                  batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 160, 240, 64) 55360       concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 160, 240, 64) 256         conv2d_52[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 160, 240, 64) 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 160, 240, 64) 36928       dropout_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 160, 240, 64) 256         conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 320, 480, 16) 4112        batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 320, 480, 48) 0           conv2d_transpose_11[0][0]
#                                                                  batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 320, 480, 32) 13856       concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 320, 480, 32) 128         conv2d_54[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 320, 480, 32) 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 320, 480, 32) 9248        dropout_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 320, 480, 32) 128         conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 320, 480, 1)  33          batch_normalization_53[0][0]
# ==================================================================================================
# Total params: 7,031,793
# Trainable params: 7,025,905
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %% [markdown]
# # Make an initial prediction

# %%
pred = model.predict(X_train[:1], verbose=1)
pred_mask = np.where(pred >= 0.5, 255, 0)
pred_mask = np.repeat(pred_mask, 3, axis=3)

fig = plt.figure(figsize=(15, 10))
for i, img in enumerate([X_train, pred_mask]):
  plt.subplot(1, 2, i+1)
  plt.imshow(img[0])
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
plt.show()
# Out:
# 1/1 [==============================] - 0s 403ms/step

# %% [markdown]
# # Model training

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

earlystopper = EarlyStopping(patience=15, verbose=1)
checkpointer = ModelCheckpoint(os.path.join(ROOT, 'model_unet_checkpoint.h5'), verbose=1, save_best_only=True)
results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=16, epochs=100, 
                    callbacks=[earlystopper, checkpointer])
# Out:
# Epoch 1/100
# 57/57 [==============================] - 54s 833ms/step - loss: 0.2977 - accuracy: 0.8946 - val_loss: 1.1902 - val_accuracy: 0.7983
#
# Epoch 00001: val_loss improved from inf to 1.19020, saving model to /content/drive/My Drive/Colab Notebooks/Carvana_UNet/model_unet_checkpoint.h5
# Epoch 2/100
# 57/57 [==============================] - 44s 772ms/step - loss: 0.0501 - accuracy: 0.9863 - val_loss: 1.1520 - val_accuracy: 0.8364
#
# Epoch 00002: val_loss improved from 1.19020 to 1.15204, saving model to /content/drive/My Drive/Colab Notebooks/Carvana_UNet/model_unet_checkpoint.h5
# Epoch 3/100
# 57/57 [==============================] - 44s 781ms/step - loss: 0.0295 - accuracy: 0.9916 - val_loss: 0.9239 - val_accuracy: 0.8636
#
# Epoch 00003: val_loss improved from 1.15204 to 0.92393, saving model to /content/drive/My Drive/Colab Notebooks/Carvana_UNet/model_unet_checkpoint.h5
# Epoch 4/100
# 57/57 [==============================] - 44s 778ms/step - loss: 0.0279 - accuracy: 0.9912 - val_loss: 0.8870 - val_accuracy: 0.9363
#
# Epoch 00004: val_loss improved from 0.92393 to 0.88697, saving model to /content/drive/My Drive/Colab Notebooks/Carvana_UNet/model_unet_checkpoint.h5
# Epoch 5/100
# 57/57 [==============================] - 44s 781ms/step - loss: 0.0295 - accuracy: 0.9902 - val_loss: 0.1189 - val_accuracy: 0.9730
#
# Epoch 00005: val_loss improved from 0.88697 to 0.11890, saving model to /content/drive/My Drive/Colab Notebooks/Carvana_UNet/model_unet_checkpoint.h5
# Epoch 6/100
# 57/57 [==============================] - 44s 778ms/step - loss: 0.0198 - accuracy: 0.9932 - val_loss: 0.0615 - val_accuracy: 0.9802
#
# Epoch 00006: val_loss improved from 0.11890 to 0.06146, saving model to /content/drive/My Drive/Colab Notebooks/Carvana_UNet/model_unet_checkpoint.h5
# Epoch 7/100
# 57/57 [==============================] - 44s 781ms/step - loss: 0.0163 - accuracy: 0.9943 - val_loss: 0.0372 - val_accuracy: 0.9882
#
# Epoch 00007: val_loss improved from 0.06146 to 0.03722, saving model to /content/drive/My Drive/Colab Notebooks/Carvana_UNet/model_unet_checkpoint.h5
# Epoch 8/100
# 57/57 [==============================] - 44s 779ms/step - loss: 0.0154 - accuracy: 0.9945 - val_loss: 0.0670 - val_accuracy: 0.9798
#
# Epoch 00008: val_loss did not improve from 0.03722
# Epoch 9/100
# 57/57 [==============================] - 44s 778ms/step - loss: 0.0146 - accuracy: 0.9948 - val_loss: 0.0428 - val_accuracy: 0.9865
#
# Epoch 00009: val_loss did not improve from 0.03722
# Epoch 10/100
# 57/57 [==============================] - 44s 781ms/step - loss: 0.0124 - accuracy: 0.9956 - val_loss: 0.0433 - val_accuracy: 0.9864
#
# Epoch 00010: val_loss did not improve from 0.03722
# Epoch 11/100
# 57/57 [==============================] - 44s 779ms/step - loss: 0.0119 - accuracy: 0.9957 - val_loss: 0.0166 - val_accuracy: 0.9940
#
# Epoch 00011: val_loss improved from 0.03722 to 0.01659, saving model to /content/drive/My Drive/Colab Notebooks/Carvana_UNet/model_unet_checkpoint.h5
# Epoch 12/100
# 57/57 [==============================] - 44s 780ms/step - loss: 0.0112 - accuracy: 0.9959 - val_loss: 0.0200 - val_accuracy: 0.9929
#
# Epoch 00012: val_loss did not improve from 0.01659
# Epoch 13/100
# 57/57 [==============================] - 44s 779ms/step - loss: 0.0107 - accuracy: 0.9960 - val_loss: 0.0180 - val_accuracy: 0.9939
#
# Epoch 00013: val_loss did not improve from 0.01659
# Epoch 14/100
# 57/57 [==============================] - 44s 780ms/step - loss: 0.0095 - accuracy: 0.9965 - val_loss: 0.0192 - val_accuracy: 0.9935
#
# Epoch 00014: val_loss did not improve from 0.01659
# Epoch 15/100
# 57/57 [==============================] - 45s 782ms/step - loss: 0.0100 - accuracy: 0.9963 - val_loss: 0.0167 - val_accuracy: 0.9945
#
# Epoch 00015: val_loss did not improve from 0.01659
# Epoch 16/100
# 57/57 [==============================] - 44s 780ms/step - loss: 0.0100 - accuracy: 0.9962 - val_loss: 0.0182 - val_accuracy: 0.9941
#
# Epoch 00016: val_loss did not improve from 0.01659
# Epoch 17/100
# 57/57 [==============================] - 44s 779ms/step - loss: 0.0098 - accuracy: 0.9963 - val_loss: 0.0144 - val_accuracy: 0.9948
#
# Epoch 00017: val_loss improved from 0.01659 to 0.01444, saving model to /content/drive/My Drive/Colab Notebooks/Carvana_UNet/model_unet_checkpoint.h5
# Epoch 18/100
# 57/57 [==============================] - 44s 780ms/step - loss: 0.0087 - accuracy: 0.9967 - val_loss: 0.0128 - val_accuracy: 0.9955
#
# Epoch 00018: val_loss improved from 0.01444 to 0.01275, saving model to /content/drive/My Drive/Colab Notebooks/Carvana_UNet/model_unet_checkpoint.h5
# Epoch 19/100
# 57/57 [==============================] - 44s 781ms/step - loss: 0.0081 - accuracy: 0.9969 - val_loss: 0.0141 - val_accuracy: 0.9952
#
# Epoch 00019: val_loss did not improve from 0.01275
# Epoch 20/100
# 57/57 [==============================] - 45s 781ms/step - loss: 0.0074 - accuracy: 0.9972 - val_loss: 0.0137 - val_accuracy: 0.9954
#
# Epoch 00020: val_loss did not improve from 0.01275
# Epoch 21/100
# 57/57 [==============================] - 45s 781ms/step - loss: 0.0072 - accuracy: 0.9972 - val_loss: 0.0110 - val_accuracy: 0.9961
#
# Epoch 00021: val_loss improved from 0.01275 to 0.01103, saving model to /content/drive/My Drive/Colab Notebooks/Carvana_UNet/model_unet_checkpoint.h5
# Epoch 22/100
# 57/57 [==============================] - 44s 780ms/step - loss: 0.0073 - accuracy: 0.9972 - val_loss: 0.0136 - val_accuracy: 0.9955
#
# Epoch 00022: val_loss did not improve from 0.01103
# Epoch 23/100
# 57/57 [==============================] - 44s 781ms/step - loss: 0.0075 - accuracy: 0.9971 - val_loss: 0.0168 - val_accuracy: 0.9950
#
# Epoch 00023: val_loss did not improve from 0.01103
# Epoch 24/100
# 57/57 [==============================] - 44s 781ms/step - loss: 0.0068 - accuracy: 0.9974 - val_loss: 0.0134 - val_accuracy: 0.9957
#
# Epoch 00024: val_loss did not improve from 0.01103
# Epoch 25/100
# 57/57 [==============================] - 44s 780ms/step - loss: 0.0065 - accuracy: 0.9975 - val_loss: 0.0144 - val_accuracy: 0.9955
#
# Epoch 00025: val_loss did not improve from 0.01103
# Epoch 26/100
# 57/57 [==============================] - 44s 780ms/step - loss: 0.0063 - accuracy: 0.9976 - val_loss: 0.0125 - val_accuracy: 0.9958
#
# Epoch 00026: val_loss did not improve from 0.01103
# Epoch 27/100
# 57/57 [==============================] - 44s 780ms/step - loss: 0.0062 - accuracy: 0.9976 - val_loss: 0.0114 - val_accuracy: 0.9962
#
# Epoch 00027: val_loss did not improve from 0.01103
# Epoch 28/100
# 57/57 [==============================] - 44s 777ms/step - loss: 0.0454 - accuracy: 0.9849 - val_loss: 14042.0684 - val_accuracy: 0.2219
#
# Epoch 00028: val_loss did not improve from 0.01103
# Epoch 29/100
# 57/57 [==============================] - 44s 776ms/step - loss: 0.0237 - accuracy: 0.9911 - val_loss: 200.9140 - val_accuracy: 0.2474
#
# Epoch 00029: val_loss did not improve from 0.01103
# Epoch 30/100
# 57/57 [==============================] - 44s 778ms/step - loss: 0.0168 - accuracy: 0.9936 - val_loss: 18.3256 - val_accuracy: 0.5143
#
# Epoch 00030: val_loss did not improve from 0.01103
# Epoch 31/100
# 57/57 [==============================] - 44s 778ms/step - loss: 0.0148 - accuracy: 0.9944 - val_loss: 2.5588 - val_accuracy: 0.7729
#
# Epoch 00031: val_loss did not improve from 0.01103
# Epoch 32/100
# 57/57 [==============================] - 44s 776ms/step - loss: 0.0132 - accuracy: 0.9950 - val_loss: 0.4874 - val_accuracy: 0.8926
#
# Epoch 00032: val_loss did not improve from 0.01103
# Epoch 33/100
# 57/57 [==============================] - 44s 775ms/step - loss: 0.0115 - accuracy: 0.9957 - val_loss: 0.0231 - val_accuracy: 0.9931
#
# Epoch 00033: val_loss did not improve from 0.01103
# Epoch 34/100
# 57/57 [==============================] - 44s 776ms/step - loss: 0.0108 - accuracy: 0.9960 - val_loss: 0.0212 - val_accuracy: 0.9930
#
# Epoch 00034: val_loss did not improve from 0.01103
# Epoch 35/100
# 57/57 [==============================] - 44s 778ms/step - loss: 0.0099 - accuracy: 0.9962 - val_loss: 0.0147 - val_accuracy: 0.9948
#
# Epoch 00035: val_loss did not improve from 0.01103
# Epoch 36/100
# 57/57 [==============================] - 45s 782ms/step - loss: 0.0100 - accuracy: 0.9962 - val_loss: 0.0174 - val_accuracy: 0.9939
#
# Epoch 00036: val_loss did not improve from 0.01103
# Epoch 00036: early stopping

# %%
while True:pass

# %% [markdown]
# # Predict training set

# %%
NUM_SAMPLES = 3
inds = np.random.choice(X_train.shape[0], NUM_SAMPLES, replace=False)
X_test = X_train[inds]
pred = model.predict(X_test, verbose=1)
# Out:
# 1/1 [==============================] - 0s 68ms/step

# %%
pred_mask = np.where(pred >= 0.5, 255, 0)
pred_mask = np.repeat(pred_mask, 3, axis=3)

fig = plt.figure(figsize=(15, 25))
fig.subplots_adjust(wspace=0, hspace=0.01)
for i, (img, mask) in enumerate(zip(X_test, pred_mask)):
  plt.subplot(NUM_SAMPLES, 2, 2*i+1)
  plt.imshow(img)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.subplot(NUM_SAMPLES, 2, 2*i+2)
  plt.imshow(mask)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
plt.show()

# %% [markdown]
# # Predict test set

# %%
import numpy as np
from PIL import Image

TEST_ROOT = 'test_12'

_,_,pred_files = next(os.walk(os.path.join(ROOT, TEST_ROOT)))
X_test = np.zeros((len(pred_files), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)

for i, img_path in enumerate(pred_files): 
  img = Image.open(os.path.join(ROOT, TEST_ROOT, img_path))
  img = img.resize((IMG_WIDTH, IMG_HEIGHT))
  img_arr = np.asarray(img)
  X_test[i] = img_arr

# %%
import keras

model_path = '/content/drive/MyDrive/Colab Notebooks/Carvana_UNet/model_unet_checkpoint.h5'
model = keras.models.load_model(model_path)
Y_test = model.predict(X_test, verbose=1)
# Out:
# 1/1 [==============================] - 7s 7s/step

# %%
pred_mask = np.where(Y_test >= 0.5, 255, 0)
pred_mask = np.repeat(pred_mask, 3, axis=3)

ROWS = Y_test.shape[0]
fig = plt.figure(figsize=(15, 5 * ROWS))
fig.subplots_adjust(wspace=0, hspace=0.01)
for i, (img, mask) in enumerate(zip(X_test, pred_mask)):
  plt.subplot(ROWS, 2, 2*i+1)
  plt.imshow(img)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.subplot(ROWS, 2, 2*i+2)
  plt.imshow(mask)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
